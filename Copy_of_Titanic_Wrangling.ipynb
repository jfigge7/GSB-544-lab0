# %% [markdown]
# # Titanic Wrangling
#
# In this practice activity you'll continue to work with the titanic dataset in ways that flex what you've learned about both data wrangling and data visualization.

# %%
# Import the titanic dataset here
import numpy as np
import pandas as pd

df = pd.read_csv("https://dlsun.github.io/pods/data/titanic.csv")
# Out:
#                                 name  gender   age             class embarked  \
# 0                Abbing, Mr. Anthony    male  42.0               3rd        S
# 1          Abbott, Mr. Eugene Joseph    male  13.0               3rd        S
# 2        Abbott, Mr. Rossmore Edward    male  16.0               3rd        S
# 3     Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0               3rd        S
# 4        Abelseth, Miss. Karen Marie  female  16.0               3rd        S
# ...                              ...     ...   ...               ...      ...
# 2202                Wynn, Mr. Walter    male  41.0         deck crew        B
# 2203             Yearsley, Mr. Harry    male  40.0  victualling crew        S
# 2204        Young, Mr. Francis James    male  32.0  engineering crew        S
# 2205             Zanetti, Sig. Minio    male  20.0  restaurant staff        S
# 2206              Zarracchi, Sig. L.    male  26.0  restaurant staff        S
#
# ...

# %%
set(df['class'])
# Out:
# {'1st',
#  '2nd',
#  '3rd',
#  'deck crew',
#  'engineering crew',
#  'restaurant staff',
#  'victualling crew'}

# %% [markdown]
# ## 1. Filter the data to include passengers only. Calculate the joint distribution (cross-tab) between a passenger's class and where they embarked.

# %%
df[df['class'].isin(["1st", "2nd", "3rd"])]
# Out:
#                                 name  gender   age class embarked  \
# 0                Abbing, Mr. Anthony    male  42.0   3rd        S
# 1          Abbott, Mr. Eugene Joseph    male  13.0   3rd        S
# 2        Abbott, Mr. Rossmore Edward    male  16.0   3rd        S
# 3     Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0   3rd        S
# 4        Abelseth, Miss. Karen Marie  female  16.0   3rd        S
# ...                              ...     ...   ...   ...      ...
# 1314          Yvois, Miss. Henriette  female  24.0   2nd        S
# 1315       Zakarian, Mr. Mapriededer    male  22.0   3rd        C
# 1316             Zakarian, Mr. Ortin    male  27.0   3rd        C
# 1317               Zenni, Mr. Philip    male  25.0   3rd        C
# 1318             Zimmermann, Mr. Leo    male  29.0   3rd        S
#
#             country  ticketno     fare  survived       type
# 0     United States    5547.0   7.1100         0  passenger
# ...

# %%
# Code here
df['type'] = df['class'].map({
    "1st": "passenger",
    "2nd": "passenger",
    "3rd": "passenger",
    "victualling crew": "crew",
    "engineering crew": "crew",
    "deck crew": "crew",
    "restaurant staff": "crew"
})

# %%
passenger_df = df[df['type'] == "passenger"]

# %%
pd.crosstab(passenger_df['class'], passenger_df['embarked'])

# %%
pd.crosstab(passenger_df['class'], passenger_df['embarked'], normalize=True)
# Out:
# embarked         B         C         Q         S
# class
# 1st       0.002278  0.108580  0.002278  0.132878
# 2nd       0.004556  0.019742  0.005315  0.186029
# 3rd       0.000000  0.077449  0.085801  0.375095

# %% [markdown]
# ## 2. Using the joint distribution that calculated above, calculate the following:
#
# * the conditional distribution of their class given where they embarked
# * the conditional distribution of where they embarked given their class
#
# Use the conditional distributions that you calculate to answer the following quesitons:
#
# * What proportion of 3rd class passengers embarked at Southampton?
# * What proportion of Southampton passengers were in 3rd class?

# %%
# Conditional distribution of class given embarked
passenger_df.groupby("embarked")["class"].value_counts(normalize=True)
# Out:
# embarked  class
# B         2nd      0.666667
#           1st      0.333333
# C         1st      0.527675
#           3rd      0.376384
#           2nd      0.095941
# Q         3rd      0.918699
#           2nd      0.056911
#           1st      0.024390
# S         3rd      0.540481
#           2nd      0.268053
#           1st      0.191466
# Name: proportion, dtype: float64

# %% [markdown]
# We see that 54.0% of Southamptom passengers were in the 3rd class.

# %%
# Conditional distribution of embarked given class
passenger_df.groupby("class")["embarked"].value_counts(normalize=True)
# Out:
# class  embarked
# 1st    S           0.540123
#        C           0.441358
#        B           0.009259
#        Q           0.009259
# 2nd    S           0.862676
#        C           0.091549
#        Q           0.024648
#        B           0.021127
# 3rd    S           0.696756
#        Q           0.159379
#        C           0.143865
# Name: proportion, dtype: float64

# %% [markdown]
# We see that 69.7% of 3rd class passengers embarked from Southampton

# %%
# Code here
pd.crosstab(passenger_df['class'], passenger_df['embarked'], normalize=True)
# Out:
# embarked         B         C         Q         S
# class
# 1st       0.002278  0.108580  0.002278  0.132878
# 2nd       0.004556  0.019742  0.005315  0.186029
# 3rd       0.000000  0.077449  0.085801  0.375095

# %%
df.sort_values(by = ["survived", "age"], ascending=[True, False])

# %% [markdown]
# ## 3. Make a visualization showing the distribution of a passenger's class, given where they embarked.
#
# Discuss the pros and cons of using this visualization versus the distributions you calculated before, to answer the previous questions.

# %%
# Code here
from plotnine import ggplot, aes, geom_bar

# %%
(
    ggplot(passenger_df,
           aes(x="embarked",
               fill = "class"))
    + geom_bar()
)

# %% [markdown]
# We see that it is difficult to understand the counts for B and Q, so let's look at the conditional probability chart:

# %%
(
    ggplot(passenger_df,
           aes(x="embarked",
               fill = "class"))
    + geom_bar(position="fill")
)
